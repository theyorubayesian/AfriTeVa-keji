# %%
from teva.teva_tasks import TevaTasks
from teva.torch.ift import SeqioDataset
# Out:
# 2024-11-18 20:21:06.709905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-18 20:21:06.723744: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-18 20:21:06.727870: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-18 20:21:08.135750: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset = SeqioDataset(task=TevaTasks.FLAN_COLLECTION, copy_pretokenized=True)
# Out:
# 2024-11-18 20:21:19.139981: W tensorflow_io/core/kernels/audio_video_mp3_kernels.cc:271] libmp3lame.so.0 or lame functions are not available
# WARNING:absl:Task 'cot_submix' not cached so using number of input examples instead of preprocessed examples to compute rate.
# WARNING:absl:Task 'dialog_submix' not cached so using number of input examples instead of preprocessed examples to compute rate.
# WARNING:absl:Task 'flan2021_submix' not cached so using number of input examples instead of preprocessed examples to compute rate.
# WARNING:absl:Task 'niv2_submix' not cached so using number of input examples instead of preprocessed examples to compute rate.
# WARNING:absl:Task 't0_submix' not cached so using number of input examples instead of preprocessed examples to compute rate.
# WARNING:absl:Task cot_submix has no 'validation' split, skipping.
# WARNING:absl:Task dialog_submix has no 'validation' split, skipping.
# ...

# %%
flan_train_set = dataset.get_dataset("train")

# %%
for row in flan_train_set:
    print(row)
    break
# Out:
# {'inputs_pretokenized': b"Given a passage, write a short incorrect summary based on the passage.\nOne example is below.\nQ: four east timorese youths who scaled the french embassy 's fence here thursday , left the embassy on their way to portugal friday .\nA: UNK latest east javanese asylum seekers leave for peru\nRationale: The example is correct, as the location names are different from the passage\nQ: al-qaeda in iraq appointed a militant named sheikh abu hamza UNK to succeed jordanian-born abu musab al-zarqawi who was killed in a us air strike , in an internet message posted monday .\nA:", 'inputs': tensor([ 51278,    267,   9980,    260,  14820,    267,   4002,  86674,  63033,
#           2851,    330,    271,   9980,    261,   2404,   5288,    298,   8038,
#            261,   2019,    273,   1964,   7026,    364,   5773,    410,   9864,
#            266,    683,  19039,    401,    271,    259, 127450,  68488,    352,
# ...

# %%
type(row["inputs"])
# Out:
# torch.Tensor
